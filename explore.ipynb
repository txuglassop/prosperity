# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
prices = pd.read_csv('input/prices_round_0_day_-2.csv', sep=';')
trades = pd.read_csv('input/trades_round_0_day_-2_nn.csv', sep=';')

# %%
kelp_trades = trades[trades['symbol'] == 'KELP']
resin_trades = trades[trades['symbol'] == 'RAINFOREST_RESIN']
kelp_prices = prices[prices['product'] == 'KELP']
resin_prices = prices[prices['product'] == 'RAINFOREST_RESIN']

# %%
plt.plot(kelp_prices['mid_price'])

# %%
plt.plot(resin_prices['mid_price'])
