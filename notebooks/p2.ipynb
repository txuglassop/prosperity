# %% [markdown]
# Data from prosperity 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot(prices: list, product: str):
    for price in prices:
        asset = price[price['product'] == product]
        plt.figure(figsize=(15,5))
        plt.plot(asset['mid_price'])
        plt.show()

# %% [markdown]
# # Round 3

# %%
prices1 = pd.read_csv('p2_data/round3/prices_round_3_day_0.csv', sep=';')
prices2 = pd.read_csv('p2_data/round3/prices_round_3_day_1.csv', sep=';')
prices3 = pd.read_csv('p2_data/round3/prices_round_3_day_2.csv', sep=';')
prices = [prices1, prices2, prices3]

for product in np.unique(prices1['product']):
    print(f'\n\nPRINTING PRICES FOR {product}')
    plot(prices, product)
# Out:
# PRINTING PRICES FOR CHOCOLATE
# PRINTING PRICES FOR GIFT_BASKET
# PRINTING PRICES FOR ROSES
# PRINTING PRICES FOR STRAWBERRIES

# %% [markdown]
# # Round 4

# %%
prices1 = pd.read_csv('p2_data/round4/prices_round_4_day_1.csv', sep=';')
prices2 = pd.read_csv('p2_data/round4/prices_round_4_day_2.csv', sep=';')
prices3 = pd.read_csv('p2_data/round4/prices_round_4_day_3.csv', sep=';')
prices = [prices1, prices2, prices3]

for product in np.unique(prices1['product']):
    print(f'\n\nPRINTING PRICES FOR {product}')
    plot(prices, product)
# Out:
# PRINTING PRICES FOR COCONUT
# PRINTING PRICES FOR COCONUT_COUPON

# %% [markdown]
# # Round 6

# %%
prices1 = pd.read_csv('p2_data/round6/prices_round_6_day_0.csv', sep=';')
prices2 = pd.read_csv('p2_data/round6/prices_round_6_day_1.csv', sep=';')
prices3 = pd.read_csv('p2_data/round6/prices_round_6_day_2.csv', sep=';')
prices = [prices1, prices2, prices3]

for product in np.unique(prices1['product']):
    print(f'\n\nPRINTING PRICES FOR {product}')
    plot(prices, product)
# Out:
# PRINTING PRICES FOR AMETHYSTS
# PRINTING PRICES FOR STARFRUIT
